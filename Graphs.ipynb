# %%
import pandas as pd
import seaborn as sns

# %%
data = {"x": [1.0, 2.0, 3.0], "y": [2.0, 3.0, 4.0], "z": [3.0, 8.0, 2.0]}
df = pd.DataFrame(data)
print(df)
# Out:
#      x    y    z
# 0  1.0  2.0  3.0
# 1  2.0  3.0  8.0
# 2  3.0  4.0  2.0

# %%
sns.pairplot(df, x_vars=["x", "y", "z"], y_vars=["x", "y", "z"])
